# %% [markdown]
# # Regresión Lineal Simple

# %% [markdown]
# # Cómo importar las librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importar el data set

# %%
dataset = pd.read_csv('Salary_Data.csv')
dataset
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
result_X = pd.DataFrame({'Experiencia': X[:, 0]})
display(result_X)
result_y = pd.DataFrame({'Sueldo': y})
display(result_y)
# Out:
#     Experiencia
# 0           1.1
# 1           1.3
# 2           1.5
# 3           2.0
# 4           2.2
# 5           2.9
# 6           3.0
# 7           3.2
# 8           3.2
# 9           3.7
# 10          3.9
# 11          4.0
# 12          4.0
# 13          4.1
# 14          4.5
# 15          4.9
# 16          5.1
# 17          5.3
# 18          5.9
# 19          6.0
# 20          6.8
# 21          7.1
# 22          7.9
# 23          8.2
# 24          8.7
# 25          9.0
# 26          9.5
# 27          9.6
# 28         10.3
# 29         10.5
#       Sueldo
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# ...

# %% [markdown]
# # Dividir el data set en conjunto de entrenamiento y conjunto de testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 1350)

# %%
y_test
# Out:
# array([101302., 121872.,  37731.,  56957.,  56642.,  39343., 122391.,
#         83088.,  54445.,  63218.])

# %%
X_t=pd.DataFrame(X_train)
display(X_t)
X_te=pd.DataFrame(X_test)
display(X_te)
y_t=pd.DataFrame(y_train)
display(y_t)
y_te=pd.DataFrame(y_test)
display(y_te)
# Out:
#       0
# 0   9.0
# 1   8.2
# 2   1.3
# 3   6.0
# 4   8.7
# 5   4.5
# 6   3.7
# 7   2.2
# 8   9.6
# 9   5.9
# 10  4.1
# 11  9.5
# 12  3.0
# 13  5.1
# 14  7.1
# 15  4.9
# 16  3.2
# 17  6.8
# 18  2.0
# 19  4.0
#       0
# 0   7.9
# 1  10.5
# 2   1.5
# 3   4.0
# 4   2.9
# 5   1.1
# 6  10.3
# 7   5.3
# 8   3.2
# 9   3.9
#            0
# 0   105582.0
# 1   113812.0
# 2    46205.0
# 3    93940.0
# 4   109431.0
# 5    61111.0
# 6    57189.0
# 7    39891.0
# 8   112635.0
# 9    81363.0
# 10   57081.0
# 11  116969.0
# 12   60150.0
# 13   66029.0
# 14   98273.0
# 15   67938.0
# 16   64445.0
# 17   91738.0
# 18   43525.0
# 19   55794.0
#           0
# 0  101302.0
# 1  121872.0
# 2   37731.0
# 3   56957.0
# 4   56642.0
# 5   39343.0
# 6  122391.0
# 7   83088.0
# 8   54445.0
# 9   63218.0

# %% [markdown]
# # Escalado de variables

# %%
"""
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
"""
# Out:
# '\nfrom sklearn.preprocessing import StandardScaler\nsc_X = StandardScaler()\nX_train = sc_X.fit_transform(X_train)\nX_test = sc_X.transform(X_test)\n'

# %% [markdown]
# # Crear modelo de Regresión Lienal Simple con el conjunto de entrenamiento

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predecir el conjunto de test

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([100781.11189557, 125751.74641934,  39314.93460628,  63325.16010991,
#         52760.66088831,  35473.2985257 , 123830.92837905,  75810.4773718 ,
#         55641.88794875,  62364.75108977])

# %%
y_test
# Out:
# array([101302., 121872.,  37731.,  56957.,  56642.,  39343., 122391.,
#         83088.,  54445.,  63218.])

# %%
X_test
# Out:
# array([[ 7.9],
#        [10.5],
#        [ 1.5],
#        [ 4. ],
#        [ 2.9],
#        [ 1.1],
#        [10.3],
#        [ 5.3],
#        [ 3.2],
#        [ 3.9]])

# %% [markdown]
# # Visualizar los resultados de entrenamiento

# %%
plt.scatter(X_train, y_train, color = "red")
plt.plot(X_train, regression.predict(X_train), color = "blue")
plt.title("Sueldo vs Años de Experiencia (Conjunto de Entrenamiento)")
plt.xlabel("Años de Experiencia")
plt.ylabel("Sueldo (en $)")
plt.show()

# %% [markdown]
# # Visualizar los resultados de test

# %%
plt.scatter(X_test, y_test, color = "red")
plt.plot(X_train, regression.predict(X_train), color = "blue")
plt.title("Sueldo vs Años de Experiencia (Conjunto de Testing)")
plt.xlabel("Años de Experiencia")
plt.ylabel("Sueldo (en $)")
plt.show()
